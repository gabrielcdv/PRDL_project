# %% [markdown]
# # Classification model for air quality prediction in time
#
# ⚠️ Some parts of this notebook are the same as `regression_main.ipynb`. The traffic part is the exact same, so is still regression. I suppressed most of the output of the traffic prediction model training/validation as it is duplicate.
#
# The classification part intervenes in the air quality prediction.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, cohen_kappa_score
import matplotlib.pyplot as plt
from lightgbm import LGBMRegressor, LGBMClassifier
import plotly.graph_objects as go
from scipy.stats import mode
import seaborn as sns

# %% [markdown]
# Loading the dataset for classification

# %%
df=pd.read_pickle("final_dataset_classes.pkl")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7321 entries, 0 to 7320
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             7321 non-null   object
#  1   hour             7321 non-null   int32
#  2   traffic_z0       7321 non-null   float64
#  3   traffic_z1       7321 non-null   float64
#  4   traffic_z3       7321 non-null   float64
#  5   traffic_z4       7321 non-null   float64
#  6   traffic_z5       7321 non-null   float64
#  7   traffic_z6       7321 non-null   float64
#  8   traffic_z7       7321 non-null   float64
#  9   traffic_z8       7321 non-null   float64
#  10  datetime_hour_x  7321 non-null   datetime64[ns]
#  11  station_4        7321 non-null   object
#  12  station_43       7321 non-null   object
#  13  station_54       7321 non-null   object
#  14  station_58       7321 non-null   object
#  15  datetime_hour_y  7321 non-null   datetime64[ns]
#  16  datetime_hour    7321 non-null   datetime64[ns]
#  17  temperature      7321 non-null   float64
#  18  precipitation    7321 non-null   float64
#  19  humidity         7321 non-null   int64
#  20  pressure         7321 non-null   float64
#  21  cloud_cover      7321 non-null   int64
#  22  is_raining       7321 non-null   int64
#  23  wind_u           7321 non-null   float64
#  24  wind_v           7321 non-null   float64
# dtypes: datetime64[ns](3), float64(13), int32(1), int64(3), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# We will predict both traffic and air quality in the future. Here is the number of hours in the future the prediction will be made.

# %%
forecast_h = 12 # Prediction will be made for forecast_h hours in the future

# %% [markdown]
# # Predicting traffic

# %%
# Identifying the 'traffic_zN' columns
traffic_cols = [c for c in df.columns if c.startswith("traffic_")]

# Creating the target value (value forecast_h hours after) for every traffic area
for col in traffic_cols:
    df[f"target_{col}"] = df[col].shift(-forecast_h)

# This functions add lags (values from previous hours) and rolls (previous rolling means over time windows)
def add_lags_and_rolls(df, cols, lags=[1, 2, 3, 6, 12], rolls=[3, 6, 12]):
    for col in cols:
        for lag in lags:
            df[f"{col}_lag{lag}"] = df[col].shift(lag)
        for w in rolls:
            df[f"{col}_roll{w}"] = df[col].rolling(window=w).mean()
    return df

df = add_lags_and_rolls(df, traffic_cols)
df["dayofweek"] = df["datetime_hour"].dt.dayofweek
df = df.dropna().reset_index(drop=True)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7297 entries, 0 to 7296
# Data columns (total 98 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               7297 non-null   object
#  1   hour               7297 non-null   int32
#  2   traffic_z0         7297 non-null   float64
#  3   traffic_z1         7297 non-null   float64
#  4   traffic_z3         7297 non-null   float64
#  5   traffic_z4         7297 non-null   float64
#  6   traffic_z5         7297 non-null   float64
#  7   traffic_z6         7297 non-null   float64
#  8   traffic_z7         7297 non-null   float64
#  9   traffic_z8         7297 non-null   float64
#  10  datetime_hour_x    7297 non-null   datetime64[ns]
#  11  station_4          7297 non-null   object
#  12  station_43         7297 non-null   object
#  13  station_54         7297 non-null   object
#  14  station_58         7297 non-null   object
#  15  datetime_hour_y    7297 non-null   datetime64[ns]
#  16  datetime_hour      7297 non-null   datetime64[ns]
#  17  temperature        7297 non-null   float64
#  18  precipitation      7297 non-null   float64
#  19  humidity           7297 non-null   int64
#  20  pressure           7297 non-null   float64
#  21  cloud_cover        7297 non-null   int64
#  22  is_raining         7297 non-null   int64
#  23  wind_u             7297 non-null   float64
#  24  wind_v             7297 non-null   float64
#  25  target_traffic_z0  7297 non-null   float64
#  26  target_traffic_z1  7297 non-null   float64
#  27  target_traffic_z3  7297 non-null   float64
#  28  target_traffic_z4  7297 non-null   float64
#  29  target_traffic_z5  7297 non-null   float64
#  30  target_traffic_z6  7297 non-null   float64
#  31  target_traffic_z7  7297 non-null   float64
#  32  target_traffic_z8  7297 non-null   float64
#  33  traffic_z0_lag1    7297 non-null   float64
#  34  traffic_z0_lag2    7297 non-null   float64
#  35  traffic_z0_lag3    7297 non-null   float64
#  36  traffic_z0_lag6    7297 non-null   float64
#  37  traffic_z0_lag12   7297 non-null   float64
#  38  traffic_z0_roll3   7297 non-null   float64
#  39  traffic_z0_roll6   7297 non-null   float64
#  40  traffic_z0_roll12  7297 non-null   float64
#  41  traffic_z1_lag1    7297 non-null   float64
#  42  traffic_z1_lag2    7297 non-null   float64
#  43  traffic_z1_lag3    7297 non-null   float64
#  44  traffic_z1_lag6    7297 non-null   float64
#  45  traffic_z1_lag12   7297 non-null   float64
#  46  traffic_z1_roll3   7297 non-null   float64
#  47  traffic_z1_roll6   7297 non-null   float64
#  48  traffic_z1_roll12  7297 non-null   float64
#  49  traffic_z3_lag1    7297 non-null   float64
#  50  traffic_z3_lag2    7297 non-null   float64
#  51  traffic_z3_lag3    7297 non-null   float64
#  52  traffic_z3_lag6    7297 non-null   float64
#  53  traffic_z3_lag12   7297 non-null   float64
#  54  traffic_z3_roll3   7297 non-null   float64
#  55  traffic_z3_roll6   7297 non-null   float64
#  56  traffic_z3_roll12  7297 non-null   float64
#  57  traffic_z4_lag1    7297 non-null   float64
#  58  traffic_z4_lag2    7297 non-null   float64
#  59  traffic_z4_lag3    7297 non-null   float64
#  60  traffic_z4_lag6    7297 non-null   float64
#  61  traffic_z4_lag12   7297 non-null   float64
#  62  traffic_z4_roll3   7297 non-null   float64
#  63  traffic_z4_roll6   7297 non-null   float64
#  64  traffic_z4_roll12  7297 non-null   float64
#  65  traffic_z5_lag1    7297 non-null   float64
#  66  traffic_z5_lag2    7297 non-null   float64
#  67  traffic_z5_lag3    7297 non-null   float64
#  68  traffic_z5_lag6    7297 non-null   float64
#  69  traffic_z5_lag12   7297 non-null   float64
#  70  traffic_z5_roll3   7297 non-null   float64
#  71  traffic_z5_roll6   7297 non-null   float64
#  72  traffic_z5_roll12  7297 non-null   float64
#  73  traffic_z6_lag1    7297 non-null   float64
#  74  traffic_z6_lag2    7297 non-null   float64
#  75  traffic_z6_lag3    7297 non-null   float64
#  76  traffic_z6_lag6    7297 non-null   float64
#  77  traffic_z6_lag12   7297 non-null   float64
#  78  traffic_z6_roll3   7297 non-null   float64
#  79  traffic_z6_roll6   7297 non-null   float64
#  80  traffic_z6_roll12  7297 non-null   float64
#  81  traffic_z7_lag1    7297 non-null   float64
#  82  traffic_z7_lag2    7297 non-null   float64
#  83  traffic_z7_lag3    7297 non-null   float64
#  84  traffic_z7_lag6    7297 non-null   float64
#  85  traffic_z7_lag12   7297 non-null   float64
#  86  traffic_z7_roll3   7297 non-null   float64
#  87  traffic_z7_roll6   7297 non-null   float64
#  88  traffic_z7_roll12  7297 non-null   float64
#  89  traffic_z8_lag1    7297 non-null   float64
#  90  traffic_z8_lag2    7297 non-null   float64
#  91  traffic_z8_lag3    7297 non-null   float64
#  92  traffic_z8_lag6    7297 non-null   float64
#  93  traffic_z8_lag12   7297 non-null   float64
#  94  traffic_z8_roll3   7297 non-null   float64
#  95  traffic_z8_roll6   7297 non-null   float64
#  96  traffic_z8_roll12  7297 non-null   float64
#  97  dayofweek          7297 non-null   int32
# dtypes: datetime64[ns](3), float64(85), int32(2), int64(3), object(5)
# memory usage: 5.4+ MB
# None

# %% [markdown]
# Training of one model per zone

# %%
models_traffic = {}
scalers_traffic = {}
for col in traffic_cols:
    # Features : lags/rolling de la zone + temporel
    feature_cols = [c for c in df.columns if c.startswith(f"{col}_") or c in ["hour", "dayofweek"]]
    X = df[feature_cols]
    y = df[f"target_{col}"]

    # Split train/test
    split_idx = int(len(df) * 0.8)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    # Normalisation
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    scalers_traffic[col] = scaler

    # Model
    model = LGBMRegressor(n_estimators=300, learning_rate=0.05, random_state=42, verbose=-1) # verbose=-1 for no output
    model.fit(X_train_scaled, y_train)
    models_traffic[col] = model

"""     Suppress the testing output
    # Metrics
    y_pred = model.predict(X_test_scaled)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    #print(f"[TRAFFIC] {col}: MAE = {mae:.2f}, R² = {r2:.3f}")

    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=df["datetime_hour"].iloc[split_idx:],
        y=y_test,
        mode='lines',
        name='VReal values',
        line=dict(color='blue')
    ))
    fig.add_trace(go.Scatter(
        x=df["datetime_hour"].iloc[split_idx:],
        y=y_pred,
        mode='lines',
        name='Prédictions',
        line=dict(color='red', dash='dash')
    ))
    fig.update_layout(
        title=f"Traffic prediction in ({col}) for +{forecast_h}h",
        xaxis_title="Date",
        yaxis_title="Traffic",
        hovermode="x unified",
        template="plotly_white"
    )
    fig.show() """
# Out:
# '     Suppress the testing output\n    # Metrics\n    y_pred = model.predict(X_test_scaled)\n    mae = mean_absolute_error(y_test, y_pred)\n    r2 = r2_score(y_test, y_pred)\n    #print(f"[TRAFFIC] {col}: MAE = {mae:.2f}, R² = {r2:.3f}")\n\n    fig = go.Figure()\n    fig.add_trace(go.Scatter(\n        x=df["datetime_hour"].iloc[split_idx:],\n        y=y_test,\n        mode=\'lines\',\n        name=\'VReal values\',\n        line=dict(color=\'blue\')\n    ))\n    fig.add_trace(go.Scatter(\n        x=df["datetime_hour"].iloc[split_idx:],\n        y=y_pred,\n        mode=\'lines\',\n        name=\'Prédictions\',\n        line=dict(color=\'red\', dash=\'dash\')\n    ))\n    fig.update_layout(\n        title=f"Traffic prediction in ({col}) for +{forecast_h}h",\n        xaxis_title="Date",\n        yaxis_title="Traffic",\n        hovermode="x unified",\n        template="plotly_white"\n    )\n    fig.show() '

# %% [markdown]
# # Predicting air quality
# First with real traffic values. (Later I will use the predicted ones)

# %%
print(df.info())

# Identify the station cols
station_cols = [c for c in df.columns if c.startswith("station_")]
weather_cols = ["temperature", "wind_u", "wind_v", "precipitation", "is_raining", "humidity", "pressure", "cloud_cover"]
weather_cols = [c for c in weather_cols if c in df.columns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7297 entries, 0 to 7296
# Data columns (total 98 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               7297 non-null   object
#  1   hour               7297 non-null   int32
#  2   traffic_z0         7297 non-null   float64
#  3   traffic_z1         7297 non-null   float64
#  4   traffic_z3         7297 non-null   float64
#  5   traffic_z4         7297 non-null   float64
#  6   traffic_z5         7297 non-null   float64
#  7   traffic_z6         7297 non-null   float64
#  8   traffic_z7         7297 non-null   float64
#  9   traffic_z8         7297 non-null   float64
#  10  datetime_hour_x    7297 non-null   datetime64[ns]
#  11  station_4          7297 non-null   object
#  12  station_43         7297 non-null   object
#  13  station_54         7297 non-null   object
#  14  station_58         7297 non-null   object
#  15  datetime_hour_y    7297 non-null   datetime64[ns]
#  16  datetime_hour      7297 non-null   datetime64[ns]
#  17  temperature        7297 non-null   float64
#  18  precipitation      7297 non-null   float64
#  19  humidity           7297 non-null   int64
#  20  pressure           7297 non-null   float64
#  21  cloud_cover        7297 non-null   int64
#  22  is_raining         7297 non-null   int64
#  23  wind_u             7297 non-null   float64
#  24  wind_v             7297 non-null   float64
#  25  target_traffic_z0  7297 non-null   float64
#  26  target_traffic_z1  7297 non-null   float64
#  27  target_traffic_z3  7297 non-null   float64
#  28  target_traffic_z4  7297 non-null   float64
#  29  target_traffic_z5  7297 non-null   float64
#  30  target_traffic_z6  7297 non-null   float64
#  31  target_traffic_z7  7297 non-null   float64
#  32  target_traffic_z8  7297 non-null   float64
#  33  traffic_z0_lag1    7297 non-null   float64
#  34  traffic_z0_lag2    7297 non-null   float64
#  35  traffic_z0_lag3    7297 non-null   float64
#  36  traffic_z0_lag6    7297 non-null   float64
#  37  traffic_z0_lag12   7297 non-null   float64
#  38  traffic_z0_roll3   7297 non-null   float64
#  39  traffic_z0_roll6   7297 non-null   float64
#  40  traffic_z0_roll12  7297 non-null   float64
#  41  traffic_z1_lag1    7297 non-null   float64
#  42  traffic_z1_lag2    7297 non-null   float64
#  43  traffic_z1_lag3    7297 non-null   float64
#  44  traffic_z1_lag6    7297 non-null   float64
#  45  traffic_z1_lag12   7297 non-null   float64
#  46  traffic_z1_roll3   7297 non-null   float64
#  47  traffic_z1_roll6   7297 non-null   float64
#  48  traffic_z1_roll12  7297 non-null   float64
#  49  traffic_z3_lag1    7297 non-null   float64
#  50  traffic_z3_lag2    7297 non-null   float64
#  51  traffic_z3_lag3    7297 non-null   float64
#  52  traffic_z3_lag6    7297 non-null   float64
#  53  traffic_z3_lag12   7297 non-null   float64
#  54  traffic_z3_roll3   7297 non-null   float64
#  55  traffic_z3_roll6   7297 non-null   float64
#  56  traffic_z3_roll12  7297 non-null   float64
#  57  traffic_z4_lag1    7297 non-null   float64
#  58  traffic_z4_lag2    7297 non-null   float64
#  59  traffic_z4_lag3    7297 non-null   float64
#  60  traffic_z4_lag6    7297 non-null   float64
#  61  traffic_z4_lag12   7297 non-null   float64
#  62  traffic_z4_roll3   7297 non-null   float64
#  63  traffic_z4_roll6   7297 non-null   float64
#  64  traffic_z4_roll12  7297 non-null   float64
#  65  traffic_z5_lag1    7297 non-null   float64
#  66  traffic_z5_lag2    7297 non-null   float64
#  67  traffic_z5_lag3    7297 non-null   float64
#  68  traffic_z5_lag6    7297 non-null   float64
#  69  traffic_z5_lag12   7297 non-null   float64
#  70  traffic_z5_roll3   7297 non-null   float64
#  71  traffic_z5_roll6   7297 non-null   float64
#  72  traffic_z5_roll12  7297 non-null   float64
#  73  traffic_z6_lag1    7297 non-null   float64
#  74  traffic_z6_lag2    7297 non-null   float64
#  75  traffic_z6_lag3    7297 non-null   float64
#  76  traffic_z6_lag6    7297 non-null   float64
#  77  traffic_z6_lag12   7297 non-null   float64
#  78  traffic_z6_roll3   7297 non-null   float64
#  79  traffic_z6_roll6   7297 non-null   float64
#  80  traffic_z6_roll12  7297 non-null   float64
#  81  traffic_z7_lag1    7297 non-null   float64
#  82  traffic_z7_lag2    7297 non-null   float64
#  83  traffic_z7_lag3    7297 non-null   float64
#  84  traffic_z7_lag6    7297 non-null   float64
#  85  traffic_z7_lag12   7297 non-null   float64
#  86  traffic_z7_roll3   7297 non-null   float64
#  87  traffic_z7_roll6   7297 non-null   float64
#  88  traffic_z7_roll12  7297 non-null   float64
#  89  traffic_z8_lag1    7297 non-null   float64
#  90  traffic_z8_lag2    7297 non-null   float64
#  91  traffic_z8_lag3    7297 non-null   float64
#  92  traffic_z8_lag6    7297 non-null   float64
#  93  traffic_z8_lag12   7297 non-null   float64
#  94  traffic_z8_roll3   7297 non-null   float64
#  95  traffic_z8_roll6   7297 non-null   float64
#  96  traffic_z8_roll12  7297 non-null   float64
#  97  dayofweek          7297 non-null   int32
# dtypes: datetime64[ns](3), float64(85), int32(2), int64(3), object(5)
# memory usage: 5.4+ MB
# None

# %% [markdown]
# Creation of the `target column`: this is the value we will try to predict for a given hour. It is the air quality labeled by station 4 in `forecast_h` hours.

# %%
# Target: Can be either the mean of all the stations, or one specific station.


target, target_label = df[['station_4']], "Air quality in station 4"

# %%
df["air_quality_selected"] = target
df["target_air_quality"] = df["air_quality_selected"].shift(-forecast_h)



# We can't add rolls of classes as in add_lags_and_rolls, so instead I will add modes (most frequent label over a period)
def add_lags_and_modes(df, cols, lags=[1, 2, 3, 6, 12], windows=[3, 6, 12]):
    for col in cols:
        # Adding lags
        for lag in lags:
            df[f"{col}_lag{lag}"] = df[col].shift(lag)
        # Adding rolling modes
        for w in windows:
            df[f"{col}_mode{w}"] = None  # Init a column to store the mode
            for i in range(len(df)):
                start = max(0, i - w + 1)
                window = df[col].iloc[start:i+1]                
                # calculer le mode avec pands
                mode_result = window.mode()
                if not mode_result.empty:
                    current_mode = mode_result.iloc[0]
                    df.at[i, f"{col}_mode{w}"] = current_mode
                else:
                    # Utiliser la dernière valeur valide
                    last_valid = window.last_valid_index()
                    if last_valid is not None:
                        df.at[i, f"{col}_mode{w}"] = df[col].iloc[last_valid]
                        print(f"    Utilisation de la dernière valeur valide: {df[col].iloc[last_valid]}")
    return df


# Create Lags/rolling for air_quality + weather
df = add_lags_and_modes(df, ["air_quality_selected"] + weather_cols)
df = df.dropna().reset_index(drop=True) # By creating lags, we will loose forecast_h rows

"""# Ajout des prédictions de trafic (ou des données réelles)
use_predicted_traffic = True  # Option true/False
 if use_predicted_traffic:
    for col in traffic_cols:
        # Prédire le trafic pour toute la période (exemple simplifié..)
        feature_cols = [c for c in df.columns if c.startswith(f"{col}_") or c in ["hour", "dayofweek"]]
        X_traffic = df[feature_cols]
        X_traffic_scaled = scalers_traffic[col].transform(X_traffic)
        df[f"predicted_{col}"] = models_traffic[col].predict(X_traffic_scaled)
    traffic_features = [f"predicted_{col}" for col in traffic_cols]
else:
    traffic_features = traffic_cols """
traffic_features = traffic_cols

# %%
# Get the created features names
feature_cols_air = (
    traffic_features +
    [c for c in df.columns if any(x in c for x in ["_lag", "_mode"]) and "air_quality" in c] +
    [c for c in df.columns if any(x in c for x in ["_lag", "_mode"]) and c.split("_")[0] in weather_cols] +
    ["hour", "dayofweek"]
)

print(feature_cols_air)
# Out:
# ['traffic_z0', 'traffic_z1', 'traffic_z3', 'traffic_z4', 'traffic_z5', 'traffic_z6', 'traffic_z7', 'traffic_z8', 'air_quality_selected_lag1', 'air_quality_selected_lag2', 'air_quality_selected_lag3', 'air_quality_selected_lag6', 'air_quality_selected_lag12', 'air_quality_selected_mode3', 'air_quality_selected_mode6', 'air_quality_selected_mode12', 'temperature_lag1', 'temperature_lag2', 'temperature_lag3', 'temperature_lag6', 'temperature_lag12', 'temperature_mode3', 'temperature_mode6', 'temperature_mode12', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'precipitation_lag6', 'precipitation_lag12', 'precipitation_mode3', 'precipitation_mode6', 'precipitation_mode12', 'humidity_lag1', 'humidity_lag2', 'humidity_lag3', 'humidity_lag6', 'humidity_lag12', 'humidity_mode3', 'humidity_mode6', 'humidity_mode12', 'pressure_lag1', 'pressure_lag2', 'pressure_lag3', 'pressure_lag6', 'pressure_lag12', 'pressure_mode3', 'pressure_mode6', 'pressure_mode12', 'hour', 'dayofweek']

# %% [markdown]
# Splitting the dataset into a training dataset and testing other.
# Since I need continous time, I can not pick randomly to fill these two new datasets. I chose to take the first 80% of the timeframe as training, and the remaining part as testing. This has some flaws (for example, the seasons change), I will try other ways later.

# %%
# Split train/test
print(df.info())
X = df[feature_cols_air]
y = df["target_air_quality"]

print(X.info())

split_idx = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]


# Important: we removed some rows from X, we have to remove the corresponding ones from Y
y_test = y_test.loc[X_test.index]  # Have the same indexes as X_test
y_train = y_train.loc[X_train.index]

print("xtrain")
print(X_train)

print("ytrain")
print(y_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Columns: 172 entries, date to cloud_cover_mode12
# dtypes: datetime64[ns](3), float64(125), int32(2), int64(3), object(39)
# memory usage: 9.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7273 entries, 0 to 7272
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   traffic_z0                   7273 non-null   float64
#  1   traffic_z1                   7273 non-null   float64
#  2   traffic_z3                   7273 non-null   float64
#  3   traffic_z4                   7273 non-null   float64
#  4   traffic_z5                   7273 non-null   float64
#  5   traffic_z6                   7273 non-null   float64
#  6   traffic_z7                   7273 non-null   float64
#  7   traffic_z8                   7273 non-null   float64
#  8   air_quality_selected_lag1    7273 non-null   object
#  9   air_quality_selected_lag2    7273 non-null   object
#  10  air_quality_selected_lag3    7273 non-null   object
#  11  air_quality_selected_lag6    7273 non-null   object
#  12  air_quality_selected_lag12   7273 non-null   object
#  13  air_quality_selected_mode3   7273 non-null   object
#  14  air_quality_selected_mode6   7273 non-null   object
#  15  air_quality_selected_mode12  7273 non-null   object
#  16  temperature_lag1             7273 non-null   float64
#  17  temperature_lag2             7273 non-null   float64
#  18  temperature_lag3             7273 non-null   float64
#  19  temperature_lag6             7273 non-null   float64
#  20  temperature_lag12            7273 non-null   float64
#  21  temperature_mode3            7273 non-null   object
#  22  temperature_mode6            7273 non-null   object
#  23  temperature_mode12           7273 non-null   object
#  24  precipitation_lag1           7273 non-null   float64
#  25  precipitation_lag2           7273 non-null   float64
#  26  precipitation_lag3           7273 non-null   float64
#  27  precipitation_lag6           7273 non-null   float64
#  28  precipitation_lag12          7273 non-null   float64
#  29  precipitation_mode3          7273 non-null   object
#  30  precipitation_mode6          7273 non-null   object
#  31  precipitation_mode12         7273 non-null   object
#  32  humidity_lag1                7273 non-null   float64
#  33  humidity_lag2                7273 non-null   float64
#  34  humidity_lag3                7273 non-null   float64
#  35  humidity_lag6                7273 non-null   float64
#  36  humidity_lag12               7273 non-null   float64
#  37  humidity_mode3               7273 non-null   object
#  38  humidity_mode6               7273 non-null   object
#  39  humidity_mode12              7273 non-null   object
#  40  pressure_lag1                7273 non-null   float64
#  41  pressure_lag2                7273 non-null   float64
#  42  pressure_lag3                7273 non-null   float64
#  43  pressure_lag6                7273 non-null   float64
#  44  pressure_lag12               7273 non-null   float64
#  45  pressure_mode3               7273 non-null   object
#  46  pressure_mode6               7273 non-null   object
#  47  pressure_mode12              7273 non-null   object
#  48  hour                         7273 non-null   int32
#  49  dayofweek                    7273 non-null   int32
# dtypes: float64(28), int32(2), object(20)
# memory usage: 2.7+ MB
# None
# xtrain
#       traffic_z0  traffic_z1  traffic_z3  traffic_z4  traffic_z5  traffic_z6  \
# 0            2.0         1.0        1.00         2.0         2.0         1.0
# 1            2.0         1.0        1.00         6.0         2.0         1.0
# 2            2.0         2.0        1.65         6.0         2.0         1.0
# 3            2.0         1.0        1.00         6.0         2.0         1.0
# 4            2.0         1.0        2.00         6.0         2.0         1.0
# ...          ...         ...         ...         ...         ...         ...
# 5813         2.0         1.0        1.00         1.0         2.0         1.0
# 5814         2.0         2.0        2.00         2.0         2.0         1.0
# 5815         2.0         2.0        2.00         2.0         2.0         1.0
# 5816         2.0         2.0        2.00         2.0         2.0         3.2
# 5817         2.0         2.0        2.00         2.0         2.0         5.0
#
#       traffic_z7  traffic_z8 air_quality_selected_lag1  \
# 0            1.0        1.00                    medium
# 1            1.0        1.00                      good
# 2            1.0        1.00                      good
# 3            1.0        1.00                      good
# 4            1.0        1.00                      good
# ...          ...         ...                       ...
# 5813         1.0        1.00                      good
# 5814         1.0        1.00                      good
# 5815         1.0        1.55                      good
# 5816         2.0        2.00                      good
# 5817         2.0        2.00                      good
#
#      air_quality_selected_lag2  ... pressure_lag1 pressure_lag2 pressure_lag3  \
# 0                       medium  ...        1018.7        1018.6        1018.1
# 1                       medium  ...        1018.2        1018.7        1018.6
# 2                         good  ...        1018.0        1018.2        1018.7
# 3                         good  ...        1017.2        1018.0        1018.2
# 4                         good  ...        1017.0        1017.2        1018.0
# ...                        ...  ...           ...           ...           ...
# 5813                      good  ...        1013.0        1013.3        1013.5
# 5814                      good  ...        1013.2        1013.0        1013.3
# 5815                      good  ...        1013.5        1013.2        1013.0
# 5816                      good  ...        1013.8        1013.5        1013.2
# 5817                      good  ...        1013.8        1013.8        1013.5
#
#      pressure_lag6 pressure_lag12 pressure_mode3  pressure_mode6  \
# 0           1016.8         1016.7         1018.2          1017.3
# 1           1017.3         1015.8         1018.0          1017.8
# 2           1017.8         1015.8         1017.2          1017.2
# 3           1018.1         1015.6         1017.0          1017.0
# 4           1018.6         1015.7         1017.0          1017.0
# ...            ...            ...            ...             ...
# 5813        1013.6         1012.5         1013.0          1013.0
# 5814        1013.9         1012.7         1013.0          1013.5
# 5815        1013.7         1012.9         1013.2          1013.5
# 5816        1013.5         1013.4         1013.8          1013.8
# 5817        1013.3         1013.9         1013.8          1013.8
#
#       pressure_mode12  hour  dayofweek
# 0              1015.8     0          1
# 1              1015.6     1          1
# 2              1015.6     2          1
# 3              1015.7     3          1
# 4              1016.5     4          1
# ...               ...   ...        ...
# 5813           1013.7     5          5
# 5814           1013.5     6          5
# 5815           1013.5     7          5
# 5816           1013.5     8          5
# 5817           1013.5     9          5
#
# [5818 rows x 50 columns]
# ytrain
# 0       medium
# 1          bad
# 2          bad
# 3       medium
# 4       medium
#          ...
# 5813      good
# 5814      good
# 5815      good
# 5816    medium
# 5817    medium
# Name: target_air_quality, Length: 5818, dtype: object

# %% [markdown]
# ## Encoding the labels
#
# We need to encode the labels as integers for processing

# %%
from sklearn.preprocessing import LabelEncoder

le_y = LabelEncoder()
# Encode y_train
y_train_encoded = le_y.fit_transform(y_train)

# Encode X_train and X_test
X_train_encoded = X_train.copy()
X_test_encoded = X_test.copy()

for col in X_train_encoded.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X_train_encoded.loc[:, col] = le.fit_transform(X_train_encoded[col])
    # Convert the column to int type (not automatic)
    X_train_encoded[col] = X_train_encoded[col].astype(int)

for col in X_test_encoded.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X_test_encoded.loc[:, col] = le.fit_transform(X_test_encoded[col])
    # Convert the column to int type (not automatic)
    X_test_encoded[col] = X_test_encoded[col].astype(int)


# No need to encode y_train, because I will decode the prediction.

# %% [markdown]
# Now, the training dataset (X_train, y_train) is encoded. So the prediction will also be encoded

# %%
# Actual model for air quality prediction
model_air = LGBMClassifier(n_estimators=500, learning_rate=0.05, random_state=42)
model_air.fit(X_train_encoded, y_train_encoded)
# Out:
# LGBMClassifier(learning_rate=0.05, n_estimators=500, random_state=42)

# %%
# Predicitng
y_pred_encoded = model_air.predict(X_test_encoded)


print("PREDICT", y_pred_encoded)
# Decoding
y_pred = le_y.inverse_transform(y_pred_encoded) # As labels
print("decoded", y_pred)

# Metrics
print("Unique labels in y_test:", np.unique(y_test))
print("Unique labels in y_pred:", np.unique(y_pred))

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')  # Use 'macro' or 'micro' if needed
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
kappa = cohen_kappa_score(y_test, y_pred)

print(f"Accuracy = {accuracy:.3f}, Precision = {precision:.3f}, Recall = {recall:.3f}, F1 = {f1:.3f}, Kappa = {kappa:.3f}")
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))


report = classification_report(y_test, y_pred, output_dict=True)
report_df = pd.DataFrame(report).transpose()

# Plot


metrics = ['precision', 'recall', 'f1-score']
classes = report_df.index[:-3]  # Exclude 'accuracy', 'macro avg', 'weighted avg'

# Plot
fig, ax = plt.subplots(figsize=(8, 5))
width = 0.2
x = np.arange(len(classes))

for i, metric in enumerate(metrics):
    ax.bar(x + i * width, report_df.loc[classes, metric], width, label=metric)

ax.set_xticks(x + width)
ax.set_xticklabels(classes)
ax.set_ylabel("Score")
ax.set_title("Classification Metrics by Class")
ax.legend()
plt.show()


from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred, normalize='true')
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt=".2f", cmap="Blues", xticklabels=le_y.classes_, yticklabels=le_y.classes_)
plt.title("Normalized Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# PREDICT [1 1 1 ... 1 1 1]
# decoded ['good' 'good' 'good' ... 'good' 'good' 'good']
# Unique labels in y_test: ['bad' 'good' 'medium']
# Unique labels in y_pred: ['bad' 'good' 'medium']
# Accuracy = 0.645, Precision = 0.608, Recall = 0.645, F1 = 0.610, Kappa = 0.182
#
# Confusion Matrix:
# [[  7  34  21]
#  [  7 798 118]
#  [  9 327 134]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          bad       0.30      0.11      0.16        62
#         good       0.69      0.86      0.77       923
#       medium       0.49      0.29      0.36       470
#
#     accuracy                           0.65      1455
#    macro avg       0.49      0.42      0.43      1455
# weighted avg       0.61      0.65      0.61      1455
